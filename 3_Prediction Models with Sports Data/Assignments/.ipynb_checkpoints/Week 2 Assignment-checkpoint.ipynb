# %%
# install the packages we need

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

NBA19 = pd.read_excel("Assignment Data/NBA2019odds.xlsx")

# %%
# Step (1)
# load the data
nba19 = NBA19.copy()

# Step (2)
nba19['winprob'] = nba19.apply(lambda x: x.winodds**-1 / (x.winodds**-1 + x.loseodds**-1), axis=1)
nba19 = nba19.drop('win prob', axis=1)  # remove win prob that came with data

# Step (3)
nba19 = nba19[nba19['home']==1]

# Step (4a)
nba_gt9 = nba19[nba19['diff'] > 9]
nba_lt9 = nba19[nba19['diff'] <=9]

# Step (4b)
nba_ot = nba19[nba19['overtime']==1]
nba_noot = nba19[nba19['overtime']==0]

# Step (4c)
nba_18 = nba19[nba19['year']==2018]
nba_19 = nba19[nba19['year']==2019]

# Step (4d)
nba_mos = [nba19[nba19['month']==month] for month in nba19.month.unique()]
jan, feb, mar, apr, oct_, nov, dec = nba_mos

# %%
# Out:
#                         team                opponent  day  month  year  \
# 0      Golden State Warriors         Houston Rockets    4      1  2019
# 3         Washington Wizards         New York Knicks   17      1  2019
# 113          Detroit Pistons        Sacramento Kings   20      1  2019
# 114          Houston Rockets         Toronto Raptors   26      1  2019
# 117   Minnesota Timberwolves            Phoenix Suns   21      1  2019
# ...                      ...                     ...  ...    ...   ...
# 2423          Denver Nuggets            Phoenix Suns   26      1  2019
# 2424   Golden State Warriors           Chicago Bulls   12      1  2019
# 2428       Charlotte Hornets        Dallas Mavericks    3      1  2019
# 2431         Milwaukee Bucks              Miami Heat   16      1  2019
# 2447      Philadelphia 76ers  Minnesota Timberwolves   16      1  2019
#
#       winodds  loseodds  teampts  oppopts  diff  overtime  home  \
# 0        1.27      3.92      134      135     1         1     1
# 3        1.32      3.52      101      100     1         0     1
# 113      1.99      1.85      101      103     2         0     1
# 114      2.36      1.61      121      119     2         0     1
# 117      1.10      7.54      116      114     2         0     1
# ...       ...       ...      ...      ...   ...       ...   ...
# 2423     1.05     11.83      132       95    37         0     1
# 2424     1.05     11.31      146      109    37         0     1
# 2428     1.83      2.02       84      122    38         0     1
# 2431     1.25      4.15      124       86    38         0     1
# 2447     1.41      2.98      149      107    42         0     1
#
#                                   Game(home-away)     HAscore  win   winprob
# 0         Golden State Warriors - Houston Rockets  134:135 ET    0  0.755299
# 3            Washington Wizards - New York Knicks     101:100    1  0.727273
# 113            Detroit Pistons - Sacramento Kings     101:103    0  0.481771
# 114             Houston Rockets - Toronto Raptors     121:119    1  0.405542
# 117         Minnesota Timberwolves - Phoenix Suns     116:114    1  0.872685
# ...                                           ...         ...  ...       ...
# 2423                Denver Nuggets - Phoenix Suns      132:95    1  0.918478
# 2424        Golden State Warriors - Chicago Bulls     146:109    1  0.915049
# 2428         Charlotte Hornets - Dallas Mavericks      84:122    0  0.524675
# 2431                 Milwaukee Bucks - Miami Heat      124:86    1  0.768519
# 2447  Philadelphia 76ers - Minnesota Timberwolves     149:107    1  0.678815
#
# [221 rows x 16 columns]
